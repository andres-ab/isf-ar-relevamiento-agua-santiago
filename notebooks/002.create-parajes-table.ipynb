# %%
import pandas as pd
# import numpy as np
from sqlalchemy import create_engine

# %%
# Load connection

# %%
engine = create_engine('postgresql://postgres:andy1234@database/postgres')

# accedo a DB por defecto

# %% [markdown]
# # Load data

# %%
df = pd.read_sql("""
SELECT a.*,
        CASE WHEN a."Entidad" = 'VIVIENDA' THEN 'VIVIENDA' ELSE 'PERSONA' END as "TipoEntidad",
        b."Sexo",
        b."Edad",
        -- b."CodVisita" as "CodVisitaFromPersonas",
        -- CASE WHEN b."CodVisita" = a."CodVisita" THEN True ELSE False END as "CodVisitaCheck",
        c."Latitud",
        c."Longitud",
        c.geometry,
        d."Pregunta",
        e."Paraje"
FROM public.respuestas_array a
LEFT JOIN public.personas b on a."CodEntidad" = b."CodPersona"
LEFT JOIN public.visitas c on a."CodVisita" = c."CodVisita"
LEFT JOIN public.maestro_preguntas d on a."IdPregunta" = d."IdPregunta"
LEFT JOIN public.viviendas e on a."CodVisita" = e."CodVisita"
WHERE a."Entidad" = 'VIVIENDA';
""", engine)

df.head()
# Out:
#                                    CodVisita  \
# 0  CE_100_2888bcab266c4163_20211007172358497
# 1  CE_100_2888bcab266c4163_20211007172358497
# 2  CE_100_2888bcab266c4163_20211007172358497
# 3  CE_100_2888bcab266c4163_20211007172358497
# 4  CE_100_2888bcab266c4163_20211007172358497
#
#                                   CodEntidad   Entidad  IdPregunta  \
# 0  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          21
# 1  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          22
# 2  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          25
# 3  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          26
# 4  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          28
#
#   IdPreguntaName        Respuesta TipoEntidad  Sexo  Edad    Latitud  \
# 0    pregunta_21              {3}    VIVIENDA  None  None -28.380204
# 1    pregunta_22             {NO}    VIVIENDA  None  None -28.380204
# 2    pregunta_25      {"1 HOGAR"}    VIVIENDA  None  None -28.380204
# ...

# %%
(
    df['Paraje']
    .value_counts(dropna=False)
)
# Out:
# La Costa                  18069
# Navicha                   16675
# Colonia Alcira / El 20     8197
# Juventud                   7808
# Puente Negro               7747
# Colonia Real Sur           7621
# Vacasnioj Sur              6395
# Colonia Real Norte         6009
# Breayoj                    5663
# Santo Domingo              4931
# Bracho Laguna              4774
# Icaño Sur                  4083
# Tio Alto                   3734
# Vacasnioj                  3452
# San Roque                  3250
# Mancapa                    2703
# Cruz Pozo                  2675
# Tacon Esquina              2252
# Vacasnioj Norte            2220
# Punta Pozo                 2048
# Toropan                    1984
# San José / Saladillo       1956
# Otro Paraje                1948
# Tusca Pozo                 1906
# Caspi Cuchuna              1698
# Totora                     1628
# Taquello                   1560
# Lote 1                     1371
# Tronco Blanco              1293
# ...

# %%
(
    df['TipoEntidad']
    .value_counts(dropna=False)
)
# Out:
# VIVIENDA    89581
# PERSONA     58745
# Name: TipoEntidad, dtype: int64

# %%
parajes = pd.read_sql("""
WITH t1 as (
SELECT a.*,
        b."Latitud",
        b."Longitud",
        b.geometry
FROM public.viviendas a
LEFT JOIN public.visitas b on a."CodVisita" = b."CodVisita"
)
SELECT ;
""", engine)

df.head()
# Out:
#                                    CodVisita  \
# 0  CE_100_2888bcab266c4163_20211007172358497
# 1  CE_100_2888bcab266c4163_20211007172358497
# 2  CE_100_2888bcab266c4163_20211007172358497
# 3  CE_100_2888bcab266c4163_20211007172358497
# 4  CE_100_2888bcab266c4163_20211007172358497
#
#                                   CodEntidad   Entidad  IdPregunta  \
# 0  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          21
# 1  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          22
# 2  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          25
# 3  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          26
# 4  CV_337_2888bcab266c4163_20211007172358630  VIVIENDA          28
#
#   IdPreguntaName        Respuesta TipoEntidad  Sexo  Edad    Latitud  \
# 0    pregunta_21              {3}    VIVIENDA  None  None -28.380204
# 1    pregunta_22             {NO}    VIVIENDA  None  None -28.380204
# 2    pregunta_25      {"1 HOGAR"}    VIVIENDA  None  None -28.380204
# ...
